# %% [markdown]
# <a href="https://colab.research.google.com/github/CyberNaut-bot/LGMVIP-DATA-SCIENCE/blob/main/TASK_1_Exploratory_Data_Analysis_on_Dataset_Terrorism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Level 02: Intermediate
# Author: SUCHITA MALICK(LETS GROW MORE)
# Task 1-Exploratory Dta analysis on Dataset- Terrorism

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data.head
# Out:
# <bound method NDFrame.head of              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       1.970000e+11   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1       1.970000e+11   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 162432  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162433  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162434  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162435  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162436  2.016050e+11   2016       5    15  ...      NaN       NaN     NaN      NaN
#
# [162437 rows x 135 columns]>

# %%
data=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.tail
# Out:
# <bound method NDFrame.tail of              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       1.970000e+11   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1       1.970000e+11   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 162432  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162433  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162434  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162435  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162436  2.016050e+11   2016       5    15  ...      NaN       NaN     NaN      NaN
#
# [162437 rows x 135 columns]>

# %%
data.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       1.970000e+11   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1       1.970000e+11   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 162432  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162433  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162434  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162435  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162436  2.016050e+11   2016       5    15  ...      NaN       NaN     NaN      NaN
#
# [162437 rows x 135 columns]>

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       1.970000e+11   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1       1.970000e+11   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4       1.970010e+11   1970       1     0  ...     -9.0       1.0     1.0      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 162432  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162433  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162434  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162435  2.016050e+11   2016       5    15  ...     -9.0       0.0    -9.0      NaN
# 162436  2.016050e+11   2016       5    15  ...      NaN       NaN     NaN      NaN
#
# [162437 rows x 135 columns]>

# %%
data['iyear'].hist()

# %%
sns.lineplot(data=data['iyear'])
plt.ylabel('attack type')
plt.xlabel(' total attack on the attack type')
plt.show()

# %%
data['attacktype1'].hist
# Out:
# <bound method hist_series of 0         1
# 1         6
# 2         1
# 3         3
# 4         7
#          ..
# 162432    3
# 162433    3
# 162434    3
# 162435    3
# 162436    2
# Name: attacktype1, Length: 162437, dtype: int64>

# %%
plt.subplots(figsize=(15,6))
sns.countplot('iyear', data=data, palette='RdYlGn_r', edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('No.of terrorist activity each year')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data=data,y=data['attacktype1_txt'])
plt.ylabel('attack type')
plt.xlabel(' total attack on the attack type')
plt.show()

# %%
sns.countplot(data=data,y=data['targtype1_txt'])
plt.ylabel('Target type')
plt.xlabel(' total attack on the Target type')
plt.show()

# %%
sns.countplot(data=data,y=data['weaptype1_txt'])
plt.ylabel('Weapen type')
plt.xlabel(' total attack on the Weapen type')
plt.show()

# %%
sns.countplot(data=data,y=data['region_txt'])
plt.ylabel('regions')
plt.xlabel(' total attack on the region')
plt.show()
