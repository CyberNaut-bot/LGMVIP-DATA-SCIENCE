# %% [markdown]
# <a href="https://colab.research.google.com/github/CyberNaut-bot/LGMVIP-DATA-SCIENCE/blob/main/TASK_4_Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Level 1 : Beginner
#
# Author : SUCHITA MALICK
#
# Task 4 : Image to pencil sketch with python(LETS GROW MORE)
#
# Dataset : https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img=cv2.imread('Dog.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x602 at 0x7FF5AB837C90>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.title('Dog')
plt.axis('off')
plt.imshow(img_rgb)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=1200x602 at 0x7FF5A9962710>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=1200x602 at 0x7FF5A99CF550>

# %%
blurred = cv2.GaussianBlur(img_invert, (21, 21), 0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=1200x602 at 0x7FF5A99C3450>

# %%
final_blur = 255 - blurred
pencil = cv2.divide(img_gray, final_blur, scale=256.0)
cv2_imshow(pencil)
# Out:
# <PIL.Image.Image image mode=L size=1200x602 at 0x7FF5A9962050>

# %%
cv2_imshow(img)
cv2_imshow( pencil)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x602 at 0x7FF5A9958190>
# <PIL.Image.Image image mode=L size=1200x602 at 0x7FF5A9958190>
